# %% [markdown]
# ## Assignment 1

# %% [markdown]
# #### Charvi Upreti
#
# charvi.upreti2021@vitstudent.ac.in
#
# 21BCE1440

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Task 1: Create pandas DataFrame named df with numpy random values (4 features and 4 observations)

# %%
dict1={
    'A':np.random.randint(10,size=4),
    'B':np.random.randint(10,size=4),
    'C':np.random.randint(10,size=4),
    'D':np.random.randint(10,size=4)
}
df=pd.DataFrame(dict1)

# %%
df.shape
# Out:
# (4, 4)

# %%
df
# Out:
#    A  B  C  D
# 0  7  0  3  3
# 1  2  5  1  6
# 2  6  0  2  6
# 3  5  8  9  0

# %% [markdown]
# ### Task 2: Rename the task - 1 'df' dataframe column names to 'Random value 1', ' Random value 2', 'Random value 3' & 'Random value 4'

# %%
df.columns=['Random value 1', 'Random value 2', 'Random value 3','Random value 4']

# %%
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0               7               0               3               3
# 1               2               5               1               6
# 2               6               0               2               6
# 3               5               8               9               0

# %% [markdown]
# ### Task 3: Find the descriptive statistics of 'df' dataframe.

# %%
print(df.describe(include='all'))
## or
print("\nOR\n")
print(df.describe())
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         5.000000        3.250000        3.750000        3.750000
# std          2.160247        3.947573        3.593976        2.872281
# min          2.000000        0.000000        1.000000        0.000000
# 25%          4.250000        0.000000        1.750000        2.250000
# 50%          5.500000        2.500000        2.500000        4.500000
# 75%          6.250000        5.750000        4.500000        6.000000
# max          7.000000        8.000000        9.000000        6.000000
#
# OR
#
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         5.000000        3.250000        3.750000        3.750000
# std          2.160247        3.947573        3.593976        2.872281
# ...

# %% [markdown]
# ### Task 4: Check for null values in 'df' and find the data types of the columns.

# %%
df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df.dtypes
# Out:
# Random value 1    int32
# Random value 2    int32
# Random value 3    int32
# Random value 4    int32
# dtype: object

# %%
### deliberately putting null value to check
df.loc[0, 'Random value 1'] = np.nan
print(df)
df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0             NaN               0               3               3
# 1             2.0               5               1               6
# 2             6.0               0               2               6
# 3             5.0               8               9               0
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0            True           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %% [markdown]
# ### Task 5: Display the 'Random value 2' and 'Random value 3' columns with location method and index location method.

# %%
print(df.loc[:,['Random value 2','Random value 3']])
# Out:
#    Random value 2  Random value 3
# 0               0               3
# 1               5               1
# 2               0               2
# 3               8               9

# %%
print(df.iloc[:,[1,2]])
# Out:
#    Random value 2  Random value 3
# 0               0               3
# 1               5               1
# 2               0               2
# 3               8               9

# %% [markdown]
# #### Other questions given in class:-

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####  1: Create a pandas dataframe (DataFrame name as 'df') (10 observations and 5 features)
#
# Note:-
#
# Features = Columns
#
# Observation = rows

# %%
dict1={
    'A':np.random.randint(10,size=10),
    'B':np.random.randint(10,size=10),
    'C':np.random.randint(10,size=10),
    'D':np.random.randint(10,size=10),
    'E':np.random.randint(10,size=10)
}
df=pd.DataFrame(dict1)

# %%
df
# Out:
#    A  B  C  D  E
# 0  8  6  2  7  6
# 1  7  2  7  8  9
# 2  3  2  9  0  7
# 3  3  9  5  4  3
# 4  3  7  8  1  9
# 5  4  0  3  8  7
# 6  4  7  4  3  0
# 7  8  0  7  7  1
# 8  9  1  4  3  9
# 9  4  3  7  3  3

# %% [markdown]
# #### 2: Checking info of 'df'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       10 non-null     int32
#  1   B       10 non-null     int32
#  2   C       10 non-null     int32
#  3   D       10 non-null     int32
#  4   E       10 non-null     int32
# dtypes: int32(5)
# memory usage: 328.0 bytes

# %% [markdown]
# #### 3: Check the descriptive statistics of 'df'

# %%
df.describe()
# Out:
#                A          B          C         D          E
# count  10.000000  10.000000  10.000000  10.00000  10.000000
# mean    5.300000   3.700000   5.600000   4.40000   5.400000
# std     2.406011   3.267687   2.319004   2.91357   3.405877
# min     3.000000   0.000000   2.000000   0.00000   0.000000
# 25%     3.250000   1.250000   4.000000   3.00000   3.000000
# 50%     4.000000   2.500000   6.000000   3.50000   6.500000
# 75%     7.750000   6.750000   7.000000   7.00000   8.500000
# max     9.000000   9.000000   9.000000   8.00000   9.000000

# %% [markdown]
# #### 4: Check the 4th index observation with 'loc' slicing operator

# %%
df.loc[4]
# Out:
# A    3
# B    7
# C    8
# D    1
# E    9
# Name: 4, dtype: int32

# %% [markdown]
# #### 5: Check all the null values in your 'df'

# %%
df.isnull().any()
# Out:
# A    False
# B    False
# C    False
# D    False
# E    False
# dtype: bool
